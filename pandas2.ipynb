# %%
import pandas as pd
df=pd.read_csv(r"D:\download\Sample-Spreadsheet-100-rows.csv")
df
# Out:
#          DBN                               School Name  \
# 0     01M015                 P.S. 015 ROBERTO CLEMENTE
# 1     01M019                       P.S. 019 ASHER LEVY
# 2     01M020                      P.S. 020 ANNA SILVER
# 3     01M034            P.S. 034 FRANKLIN D. ROOSEVELT
# 4     01M063                 THE STAR ACADEMY - P.S.63
# ...      ...                                       ...
# 1824  84X703          BRONX PREPARATORY CHARTER SCHOOL
# 1825  84X704               KIPP ACADEMY CHARTER SCHOOL
# 1826  84X706             HARRIET TUBMAN CHARTER SCHOOL
# 1827  84X718  BRONX CHARTER SCHOOL FOR BETTER LEARNING
# 1828  84X730         BRONX CHARTER SCHOOL FOR THE ARTS
#
#       Total Parent \nResponse Rate %  Total Teacher Response Rate %  \
# 0                                 91                            100
# 1                                100                             93
# 2                                 58                             90
# ...

# %%
df.isnull()
# Out:
#         DBN  School Name  Total Parent \nResponse Rate %  \
# 0     False        False                           False
# 1     False        False                           False
# 2     False        False                           False
# 3     False        False                           False
# 4     False        False                           False
# ...     ...          ...                             ...
# 1824  False        False                           False
# 1825  False        False                           False
# 1826  False        False                           False
# 1827  False        False                           False
# 1828  False        False                           False
#
#       Total Teacher Response Rate %  Total Student Response Rate %  \
# 0                             False                           True
# 1                             False                           True
# 2                             False                           True
# ...

# %%
df.fillna(0)
# Out:
# Empty DataFrame
# Columns: [DBN, School Name, Total Parent
# Response Rate %, Total Teacher Response Rate %, Total Student Response Rate %, Collaborative Teachers Score, Effective School Leadership Score, Rigorous Instruction Score, Supportive Environment Score, Strong Family-Community Ties Score, Trust Score]
# Index: []

# %%
df.isnull().sum().sum()
# Out:
# 3452

# %%
df.shape
# Out:
# (1829, 11)

# %%
df.fillna(0)
# Out:
# Empty DataFrame
# Columns: [DBN, School Name, Total Parent
# Response Rate %, Total Teacher Response Rate %, Total Student Response Rate %, Collaborative Teachers Score, Effective School Leadership Score, Rigorous Instruction Score, Supportive Environment Score, Strong Family-Community Ties Score, Trust Score]
# Index: []

# %%
df.fillna(method='ffill', axis = 1)
# Out:
# Empty DataFrame
# Columns: [DBN, School Name, Total Parent
# Response Rate %, Total Teacher Response Rate %, Total Student Response Rate %, Collaborative Teachers Score, Effective School Leadership Score, Rigorous Instruction Score, Supportive Environment Score, Strong Family-Community Ties Score, Trust Score]
# Index: []

# %%
df.dropna(inplace = True)

# %%
df.ffill(inplace= True)

# %%
df['Total Parent \nResponse Rate %'].fillna(value=df['Total Parent \nResponse Rate %'].mean())
# Out:
# Series([], Name: Total Parent \nResponse Rate %, dtype: int64)

# %%
import pandas as pd
df=pd.read_csv(r"D:\download\Sample-Spreadsheet-100-rows.csv")
df
df.head()
# Out:
#       DBN                     School Name  Total Parent \nResponse Rate %  \
# 0  01M015       P.S. 015 ROBERTO CLEMENTE                              91
# 1  01M019             P.S. 019 ASHER LEVY                             100
# 2  01M020            P.S. 020 ANNA SILVER                              58
# 3  01M034  P.S. 034 FRANKLIN D. ROOSEVELT                              29
# 4  01M063       THE STAR ACADEMY - P.S.63                              80
#
#    Total Teacher Response Rate %  Total Student Response Rate %  \
# 0                            100                            NaN
# 1                             93                            NaN
# 2                             90                            NaN
# 3                            100                           95.0
# 4                            100                            NaN
#
#    Collaborative Teachers Score  Effective School Leadership Score  \
# ...

# %%
df.loc[1]
# Out:
# DBN                                                01M019
# School Name                           P.S. 019 ASHER LEVY
# Total Parent \nResponse Rate %                        100
# Total Teacher Response Rate %                          93
# Total Student Response Rate %                         NaN
# Collaborative Teachers Score                         4.53
# Effective School Leadership Score                    4.51
# Rigorous Instruction Score                            4.8
# Supportive Environment Score                          NaN
# Strong Family-Community Ties Score                   4.66
# Trust Score                                          3.76
# Name: 1, dtype: object

# %%
df.loc[5]
# Out:
# DBN                                                  01M064
# School Name                           P.S. 064 ROBERT SIMON
# Total Parent \nResponse Rate %                           52
# Total Teacher Response Rate %                            96
# Total Student Response Rate %                           NaN
# Collaborative Teachers Score                           4.56
# Effective School Leadership Score                      4.09
# Rigorous Instruction Score                             3.74
# Supportive Environment Score                            NaN
# Strong Family-Community Ties Score                     4.18
# Trust Score                                            4.04
# Name: 5, dtype: object

# %%
df.loc[[5,6,7,8]]
# Out:
#       DBN                    School Name  Total Parent \nResponse Rate %  \
# 5  01M064          P.S. 064 ROBERT SIMON                              52
# 6  01M110  P.S. 110 FLORENCE NIGHTINGALE                              79
# 7  01M134       P.S. 134 HENRIETTA SZOLD                              46
# 8  01M140         P.S. 140 NATHAN STRAUS                              57
#
#    Total Teacher Response Rate %  Total Student Response Rate %  \
# 5                             96                            NaN
# 6                             77                            NaN
# 7                             93                            NaN
# 8                             89                           87.0
#
#    Collaborative Teachers Score  Effective School Leadership Score  \
# 5                          4.56                               4.09
# 6                          3.11                               3.15
# 7                          2.51                               1.53
# ...

# %%
df.loc[5,'Rigorous Instruction Score']
# Out:
# 3.74

# %%
df.loc[5:15,'Rigorous Instruction Score']
# Out:
# 5     3.74
# 6     1.96
# 7     3.19
# 8     3.40
# 9     3.23
# 10    2.77
# 11    3.85
# 12    3.30
# 13    3.81
# 14    2.70
# 15    3.75
# Name: Rigorous Instruction Score, dtype: float64

# %%
df.loc[df['Rigorous Instruction Score']>2]
# Out:
#          DBN                               School Name  \
# 0     01M015                 P.S. 015 ROBERTO CLEMENTE
# 1     01M019                       P.S. 019 ASHER LEVY
# 3     01M034            P.S. 034 FRANKLIN D. ROOSEVELT
# 5     01M064                     P.S. 064 ROBERT SIMON
# 7     01M134                  P.S. 134 HENRIETTA SZOLD
# ...      ...                                       ...
# 1824  84X703          BRONX PREPARATORY CHARTER SCHOOL
# 1825  84X704               KIPP ACADEMY CHARTER SCHOOL
# 1826  84X706             HARRIET TUBMAN CHARTER SCHOOL
# 1827  84X718  BRONX CHARTER SCHOOL FOR BETTER LEARNING
# 1828  84X730         BRONX CHARTER SCHOOL FOR THE ARTS
#
#       Total Parent \nResponse Rate %  Total Teacher Response Rate %  \
# 0                                 91                            100
# 1                                100                             93
# 3                                 29                            100
# ...

# %% [markdown]
# # iloc()

# %%
df.iloc[0]
# Out:
# DBN                                                      01M015
# School Name                           P.S. 015 ROBERTO CLEMENTE
# Total Parent \nResponse Rate %                               91
# Total Teacher Response Rate %                               100
# Total Student Response Rate %                               NaN
# Collaborative Teachers Score                                4.1
# Effective School Leadership Score                          4.19
# Rigorous Instruction Score                                 4.02
# Supportive Environment Score                                NaN
# Strong Family-Community Ties Score                         4.18
# Trust Score                                                3.96
# Name: 0, dtype: object

# %%
df.iloc[[0,1,2,3]]
# Out:
#       DBN                     School Name  Total Parent \nResponse Rate %  \
# 0  01M015       P.S. 015 ROBERTO CLEMENTE                              91
# 1  01M019             P.S. 019 ASHER LEVY                             100
# 2  01M020            P.S. 020 ANNA SILVER                              58
# 3  01M034  P.S. 034 FRANKLIN D. ROOSEVELT                              29
#
#    Total Teacher Response Rate %  Total Student Response Rate %  \
# 0                            100                            NaN
# 1                             93                            NaN
# 2                             90                            NaN
# 3                            100                           95.0
#
#    Collaborative Teachers Score  Effective School Leadership Score  \
# 0                          4.10                               4.19
# 1                          4.53                               4.51
# 2                          2.71                               2.98
# ...

# %%
df.iloc[:,0]
# Out:
# 0       01M015
# 1       01M019
# 2       01M020
# 3       01M034
# 4       01M063
#          ...
# 1824    84X703
# 1825    84X704
# 1826    84X706
# 1827    84X718
# 1828    84X730
# Name: DBN, Length: 1829, dtype: object

# %%
df.iloc[0:5,1]
# Out:
# 0         P.S. 015 ROBERTO CLEMENTE
# 1               P.S. 019 ASHER LEVY
# 2              P.S. 020 ANNA SILVER
# 3    P.S. 034 FRANKLIN D. ROOSEVELT
# 4         THE STAR ACADEMY - P.S.63
# Name: School Name, dtype: object

# %%
df.iloc[0:5,1:4]
# Out:
#                       School Name  Total Parent \nResponse Rate %  \
# 0       P.S. 015 ROBERTO CLEMENTE                              91
# 1             P.S. 019 ASHER LEVY                             100
# 2            P.S. 020 ANNA SILVER                              58
# 3  P.S. 034 FRANKLIN D. ROOSEVELT                              29
# 4       THE STAR ACADEMY - P.S.63                              80
#
#    Total Teacher Response Rate %
# 0                            100
# 1                             93
# 2                             90
# 3                            100
# 4                            100

# %%
df.drop_duplicates()
# Out:
#          DBN                               School Name  \
# 0     01M015                 P.S. 015 ROBERTO CLEMENTE
# 1     01M019                       P.S. 019 ASHER LEVY
# 2     01M020                      P.S. 020 ANNA SILVER
# 3     01M034            P.S. 034 FRANKLIN D. ROOSEVELT
# 4     01M063                 THE STAR ACADEMY - P.S.63
# ...      ...                                       ...
# 1824  84X703          BRONX PREPARATORY CHARTER SCHOOL
# 1825  84X704               KIPP ACADEMY CHARTER SCHOOL
# 1826  84X706             HARRIET TUBMAN CHARTER SCHOOL
# 1827  84X718  BRONX CHARTER SCHOOL FOR BETTER LEARNING
# 1828  84X730         BRONX CHARTER SCHOOL FOR THE ARTS
#
#       Total Parent \nResponse Rate %  Total Teacher Response Rate %  \
# 0                                 91                            100
# 1                                100                             93
# 2                                 58                             90
# ...
